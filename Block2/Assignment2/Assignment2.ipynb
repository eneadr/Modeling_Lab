# %% [markdown]
# Adsorption Using AiiDAlab
#
# 1. AiiDAlab offers for adsorption studies 3 types of calculations :
# First Pore analysis and the pore volume, to understand the geometry of the MOF, then isotherm calculations to simulate the quantity of gas adsorbed at various pressure a ta given temperature, and then Henry coefficient.
#
# 2. The following variables were computated :
# - the density accessible surface area : 0.576983 g/cm3
# - accessible surface area : 3964.65 A^2
# - accessible probeoccupiable volume : 13737.4 A^3
# - porosity : 0.77498
#
# 3. The Henry coefficients of CO2 and CH4 are respectively 4.95112e-6 and 1.12113e-6 mol/kg/Pa. Because CO2 has the bigger Henry coefficient, it will better be absorbed by the IRMOF-1 at low pressure, meaning that this material can be used to separate the CO2 and CH4 and mainly recover the CO2.

# %% [markdown]
# 4. CO2 absorption isotherm at T= 300K :

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_CO2 = [
    0.09649599694768,
    0.3948153845504,
    0.69862192675748,
    1.02791613976,
    1.4028933499715,
    1.6763744341876,
    2.166452017609,
    2.50301914559,
    2.9011138355549,
    3.2198882965348,
    3.655126802283,
    3.9100359786074,
    4.4598553636384,
    5.0184412086882,
    5.4556602850332,
    5.9664851571657,
    6.7251411008668,
    7.0717084869433
]

plt.figure(figsize=(7,5))

plt.plot(pressure, loading_CO2, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("CO$_2$ loading (mol/kg)")
plt.title("CO$_2$ adsorption isotherm at 300 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# CH4 absorption isotherm at T= 300K :

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_CH4 = [
    0.02162393471304,
    0.08678795418612,
    0.15549102603716,
    0.22643441544856,
    0.29000748477008,
    0.35429485824128,
    0.42897211025328,
    0.48952562112388,
    0.56426780987676,
    0.6243667635612,
    0.70274540980336,
    0.76359113600792,
    0.81742369419744,
    0.88739303249564,
    0.94245938876188,
    1.0342474719958,
    1.1067168748178,
    1.1316525833158
]

plt.plot(pressure, loading_CH4, marker='o')

plt.xlabel("Pressure (bar)")
plt.ylabel("CH$_4$ loading (mol/kg)")
plt.title("CH$_4$ adsorption isotherm at 300 K")

plt.grid(True)
plt.show()

# %% [markdown]
# The isotherms confirmed the higher affinity of IRMOF-1 for CO2 compared to CH4 for pressures going from 0.2 to 10.2 bar.
