# %% [markdown]
# Mg-MOF-74
# NOTT-300
# UTSA-20
# UTSA-80
# ZIF-8
#
# 1. The density, ASA, POAV, Porosity and density have been computed for each structure. CO2 and N2 Henry coefficient were computed for each structure.

# %%
import pandas as pd

data = {
    "Material": ["Mg-MOF-74", "NOTT-300", "UTSA-20", "UTSA-80", "ZIF-8"],

    "Density (g/cm3)": [0.886275, 1.03926,0.882399 ,0.678215 ,0.909567 ],
    "ASA (A2)": [222.828, 453.452, 1307.51, 3114.62, 787.421],
    "POAV (A3)": [837.198, 1297.11, 3575.36, 9619.78, 2488.25],
    "Porosity": [0.61368,0.48999, 0.62907, 0.66798, 0.49906],

    "Henry CO2": [8.6283e-05, 0.000184514, 4.0857e-05, None, 8.83854e-06],
    "Henry N2": [3.34659e-06, 1.05544e-05, 4.38291e-06, 3.32631e-06, None]
}

df = pd.DataFrame(data)

df
# Out:
#     Material  Density (g/cm3)         ASA (A2)        POAV (A3)  \
# 0  Mg-MOF-74 8.8627500000e-01 2.2282800000e+02 8.3719800000e+02
# 1   NOTT-300 1.0392600000e+00 4.5345200000e+02 1.2971100000e+03
# 2    UTSA-20 8.8239900000e-01 1.3075100000e+03 3.5753600000e+03
# 3    UTSA-80 6.7821500000e-01 3.1146200000e+03 9.6197800000e+03
# 4      ZIF-8 9.0956700000e-01 7.8742100000e+02 2.4882500000e+03
#
#           Porosity        Henry CO2         Henry N2
# 0 6.1368000000e-01 8.6283000000e-05 3.3465900000e-06
# 1 4.8999000000e-01 1.8451400000e-04 1.0554400000e-05
# 2 6.2907000000e-01 4.0857000000e-05 4.3829100000e-06
# 3 6.6798000000e-01              NaN 3.3263100000e-06
# 4 4.9906000000e-01 8.8385400000e-06              NaN

# %% [markdown]
# 2. No Henry coefficient was found for N2 with the ZIF-8 structure with the mention : "no accessible pore volume for N2". Thus, no isotherm was found as well.
#
# Ranking of the structures based on their affinity for CO2:
#
# ZIF-8<Mg-MOF-74<UTSA-20<NOTT-300

# %% [markdown]
# 3. The N2 and CO2 isotherms were then computed for each structure.

# %% [markdown]
# CO2 Isotherm curve for Mg-MOF-74 :

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2,
    0.41002778686856,
    0.66970378509151,
    0.9980399562949,
    1.4247070989363,
    1.998369313815,
    2.598369313815,
    3.198369313815,
    3.798369313815,
    4.398369313815,
    4.998369313815,
    5.598369313815,
    6.198369313815,
    6.798369313815,
    7.398369313815,
    7.998369313815,
    8.598369313815,
    9.198369313815,
    9.798369313815,
    10.2
]

loading = [
    1.8147813540733,
    3.8121035046375,
    5.6119320670486,
    7.4334773705075,
    8.679829465424,
    9.9597781312737,
    10.706284667022,
    11.400516517798,
    12.015606727285,
    12.539280615761,
    12.698164756786,
    13.073151930468,
    13.365151968793,
    13.35766698927,
    13.687074757827,
    13.80257691891,
    13.831658467791,
    13.838285078103,
    14.137632756878,
    14.312345226161
]

plt.figure(figsize=(7,5))

plt.plot(pressure, loading, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("Loading (mol/kg)")
plt.title("Adsorption isotherm at 298 K")
plt.title("CO$_2$ adsorption isotherm at 298 K")
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# N2 Isotherm curve for Mg-MOF-74 :

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_N2 = [
    0.06585408589669,
    0.25716741572795,
    0.44800005880084,
    0.63703012652984,
    0.84786277222777,
    1.0245151559287,
    1.1557941431164,
    1.3434508201072,
    1.4994508405825,
    1.6216654488981,
    1.7415452929587,
    1.9163779339316,
    2.0347127134118,
    2.2126354835456,
    2.332875842675,
    2.4780260763185,
    2.6638286758127,
    2.661734254937
]

plt.figure(figsize=(7,5))

plt.plot(pressure, loading_N2, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("N$_2$ loading (mol/kg)")
plt.title("N$_2$ adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

# Pressures
pressure_CO2 = [ 0.2,
    0.41002778686856,
    0.66970378509151,
    0.9980399562949,
    1.4247070989363,
    1.998369313815,
    2.598369313815,
    3.198369313815,
    3.798369313815,
    4.398369313815,
    4.998369313815,
    5.598369313815,
    6.198369313815,
    6.798369313815,
    7.398369313815,
    7.998369313815,
    8.598369313815,
    9.198369313815,
    9.798369313815,
    10.2]
pressure_N2 = [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2]

# Loadings
loading_CO2 = [1.8147813540733,
    3.8121035046375,
    5.6119320670486,
    7.4334773705075,
    8.679829465424,
    9.9597781312737,
    10.706284667022,
    11.400516517798,
    12.015606727285,
    12.539280615761,
    12.698164756786,
    13.073151930468,
    13.365151968793,
    13.35766698927,
    13.687074757827,
    13.80257691891,
    13.831658467791,
    13.838285078103,
    14.137632756878,
    14.312345226161]
loading_N2 = [0.06585408589669,
    0.25716741572795,
    0.44800005880084,
    0.63703012652984,
    0.84786277222777,
    1.0245151559287,
    1.1557941431164,
    1.3434508201072,
    1.4994508405825,
    1.6216654488981,
    1.7415452929587,
    1.9163779339316,
    2.0347127134118,
    2.2126354835456,
    2.332875842675,
    2.4780260763185,
    2.6638286758127,
    2.661734254937]

plt.figure(figsize=(7, 5))

plt.plot(
    pressure_CO2,
    loading_CO2,
    marker='o',
    linewidth=2,
    color='blue',
    label='CO$_2$'
)

plt.plot(
    pressure_N2,
    loading_N2,
    marker='o',
    linewidth=2,
    color='orange',
    label='N$_2$'
)

plt.xlabel("Pressure (bar)")
plt.ylabel("Loading (mol kg$^{-1}$)")
plt.title("CO$_2$ and N$_2$ adsorption isotherms at 298 K")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# For NOTT you can find below the isotherms for N2 and CO2 :

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_N2 = [
    0.20786433486612,
    0.76997223019932,
    1.2454657943794,
    1.6987374007153,
    2.0545402202563,
    2.4281789525764,
    2.763349252617,
    3.0684409406026,
    3.3441783174992,
    3.5715987801428,
    3.8096222049961,
    4.0376965504304,
    4.2488805983953,
    4.3870711984211,
    4.5571411033117,
    4.7519177210375,
    4.8726144393446,
    4.9400951516525
]

plt.figure(figsize=(7, 5))

plt.plot(pressure, loading_N2, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("N$_2$ loading (mol/kg)")
plt.title("N$_2$ adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# isotherm for CO2:

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2,
    0.29836652833503,
    0.42612619503658,
    0.59779008990848,
    0.83863702129447,
    1.1962475223664,
    1.7696622771311,
    2.3696622771311,
    2.9696622771311,
    3.5696622771311,
    4.1696622771311,
    4.7696622771311,
    5.3696622771311,
    5.9696622771311,
    6.5696622771311,
    7.1696622771311,
    7.7696622771311,
    8.3696622771311,
    8.9696622771311,
    9.5696622771311,
    10.1696622771311,
    10.2
]

loading = [
    4.8485113107587,
    6.252106102847,
    7.5328513930618,
    8.0490768302896,
    8.604263626844,
    8.999128403157,
    9.3008098404758,
    9.5759235137309,
    9.6284453979131,
    9.7672194626144,
    9.860302204284,
    9.9183670032466,
    9.9586461880924,
    10.036367712157,
    10.139832101874,
    10.106614851977,
    10.102399822412,
    10.178964476761,
    10.331067692339,
    10.27636284538,
    10.22643637321,
    10.223086480962
]

plt.figure(figsize=(7, 5))

plt.plot(pressure, loading, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("Loading (mol/kg)")
plt.title("Adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# Isotherm N2 pour UTSA 20

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_N2 = [
    0.086434862747825,
    0.34359554853471,
    0.57527773331242,
    0.79596724449034,
    0.97515279073647,
    1.1570947829982,
    1.3749699048509,
    1.5620854069017,
    1.7337714333576,
    1.9222692972241,
    2.0940712102993,
    2.2678349182865,
    2.3897310865324,
    2.5118259175543,
    2.6516348460939,
    2.8111113894477,
    2.924928604807,
    3.0224803053896
]

plt.figure(figsize=(7,5))

plt.plot(pressure, loading_N2, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("N$_2$ loading (mol/kg)")
plt.title("N$_2$ adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# isotherm CO2 UTSA 20:

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2,
    0.57479201712798,
    1.033247233813,
    1.6054927012962,
    2.2054927012962,
    2.8054927012962,
    3.4054927012962,
    4.0054927012962,
    4.6054927012962,
    5.2054927012962,
    5.8054927012962,
    6.4054927012962,
    7.0054927012962,
    7.6054927012962,
    8.2054927012962,
    8.8054927012962,
    9.4054927012962,
    10.005492701296,
    10.2
]

loading = [
    0.82890387721142,
    2.4294388088654,
    4.1151007399926,
    5.5155574234683,
    6.4390661700865,
    7.1615778531878,
    7.653127504074,
    8.1192897077234,
    8.537764567541,
    8.8388214491862,
    9.1372874371289,
    9.4957744162405,
    9.856397020193,
    10.133374317876,
    10.426600575104,
    10.567874641616,
    10.804424064403,
    11.016496577677,
    10.966119008755
]

plt.figure(figsize=(7, 5))

plt.plot(pressure, loading, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("CO$_2$ loading (mol/kg)")
plt.title("CO$_2$ adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# isotherm N2 UTSA 80

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0,
    5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2
]

loading_N2 = [
    0.0665093660904,
    0.262331165331,
    0.4446028713267,
    0.65507135228685,
    0.81840353020875,
    0.97366005657315,
    1.1605901384147,
    1.2781376223485,
    1.4800714147152,
    1.6463108271978,
    1.8087164303621,
    1.9359206934215,
    2.0852352403767,
    2.2460767173445,
    2.408074287588,
    2.5610611308305,
    2.6996818149864,
    2.786295303112
]

plt.figure(figsize=(7, 5))

plt.plot(pressure, loading_N2, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("N$_2$ loading (mol/kg)")
plt.title("N$_2$ adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# isotherm CO2 ZIF

# %%
import matplotlib.pyplot as plt

pressure = [
    0.2,
    1.3982797169627,
    2.2
]

loading = [
    0.17618564486592,
    1.2722840662998,
    2.1072894217447
]

plt.figure(figsize=(7, 5))

plt.plot(pressure, loading, marker='o', linewidth=2)

plt.xlabel("Pressure (bar)")
plt.ylabel("Loading (mol/kg)")
plt.title("Adsorption isotherm at 298 K")

plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()
